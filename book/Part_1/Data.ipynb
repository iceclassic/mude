# %% [markdown]
# # 1. Selecting Data
#
# Describe relationship between data <---> model, discussion about source, local,regional,global data, quality,etc
#
# ## 1.2 Sources
# ```{admonition} Berkeley Earth Global Temperature
# :class: dropdown
#
# - Daily  average temperature observations
# - Resolution 1° x  1°
# - [Source](https://berkeleyearth.org/data/)
# - [License](https://berkeleyearth.org/data/)
#
# - Monthly mean temperature FAIRBANKS
# - 80 km from Nenana, data from 1828 - 2020
# - [Source](https://berkeleyearth.org/temperature-location/65.09N-147.45W)
#
# - Monthly mean temperature HEALY RIVER AIRPORT
# - 90 km from Nenana, data from 1983 - 2012
# - [Source](https://data.berkeleyearth.org/stations/43604)
#
# - Monthly mean temperature MOUNT MCKINLEY NATL
# - 100 km from Nenana, data from 1923 - 2013
# - [Source](https://data.berkeleyearth.org/stations/167750)
# ```
# ```{admonition} NOAA GHCN: Nenana
# :class: dropdown
#
# - NENANA MUNICIPAL AIRPORT, AK US (USW00026435)
#     - Rainfall
#     - Snowfall
#     - Snow-depth
# - [Source](https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} NOAA GHCN: Fairbanks
# :class: dropdown
#
# - FAIRBANKS INTERNATIONAL AIRPORT, AK US (USW00026411)
#     - Rainfall
#     - Snowfall
#     - Snow-depth
#     - Air temperature
#     - Average wind speed
#
# - [Source](https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} USGS Water Data: Nenana
# :class: dropdown
#
# - USGS 15515500 TANANA R AT NENANA AK
#     - Mean water temperature
#     - Mean discharge
#
# - [Source](https://waterdata.usgs.gov/nwis/rt)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} USGS Water Data: Fairbanks
# :class: dropdown
#
# - USGS 15485500 Tanana R at Fairbanks AK
#     - Mean water temperature
#     - Mean discharge
# - [Source](https://waterdata.usgs.gov/nwis/rt)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} USGS Water Data: Fairbanks
# :class: dropdown
#
# - USGS 15485500 Tanana R at Fairbanks AK
#     - Mean water temperature
#     - Mean discharge
# - [Source](https://waterdata.usgs.gov/nwis/rt)
# - [License](https://www.google.com/)
# ```
# ```{admonition} NERC-EDS  Global Cloud Coverage
# :class: dropdown
#
# - Global Cloud coverga percentage
# - Resolution 2° x  2°
# - [Source](https://catalogue.ceda.ac.uk/uuid/5fda109ab71947b6b7724077bf7eb753?search_url=%2F%253Fq%253DCRU%2BTS4.07%2BCloud%2BCover%2B%26results_per_page%253D20%26sort_by%253Drelevance%26objects_related_to_uuid%253D%26geo_option%253DTrue%26north_bound%253D%26west_bound%253D%26east_bound%253D%26south_bound%253D%26start_date%253D%26end_date%253D%26date_option%253Dpublication_date%26start_date_pub%253D%26end_date_pub%253D) accessed through [KNMI](https://climexp.knmi.nl/select.cgi?id=someone@somewhere&field=cru4_cld_10)
# - [License](https://www.google.com/)
# ```
# ```{admonition} TEMIS Global Solar Surface Irradiance
# :class: dropdown
#
# - Broadband Solar Surface Irradiance(0.2-4.0 micron)
# - Resolution 2° x  2°
# - [Source](https://www.temis.nl/fresco/) accessed through [KNMI](https://climexp.knmi.nl/select.cgi?id=someone@somewhere&field=fresco6_ssi)
# - [License](https://www.google.com/)
# ```
# ```{admonition} USGS Glaciers Data: Gulkana
# :class: dropdown
#
# - Gulkana weather station (USGS 15478038)
#     - Air Temperature
#     - Precipitation
#     - Glacier-wide mass balance
# - [Source](https://www.ncdc.noaa.gov/cdo-web/datasets/GHCND)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} NOAA Global Indexes
# :class: dropdown
#
# - ENSO-Southern oscillation index
# - Pacific decadal oscillation index
# - Artic oscillation
# - [Source](https://www.ncei.noaa.gov/access/monitoring/products/)
# - [License](https://www.google.com/)
# ```
#
# ```{admonition} Nenana Ice Classic
# :class: dropdown
#
# - Ice thickness measurements<!--  -->
# - Ice break up dates
# ```
# ## 1.3 Working with dataframes
# > we need to explain why use dataframes instead of numpy
#
# ::: {card} Ex 1
# The files corresponding to the sources mentioned above are available in  [`temp_path`], choose a file, import it, set the index to a datetime object, and make simple plot
#
#  Introduces useful pandas methods such as
#
#     - `pd.read_csv` [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#     - `skip_row`
#     - `index_col`
#     - `pd.index=pd.to_datetime()`
# :::
#
#
#
# ::: {card} Ex 2
# Load another file, and merge the dataframe such that the resulting dataframe contains 2 column with the variable of each file and an datetime object. (`pd.merge` [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html))
#
# - Pay special attention to difference between left, right and outer merge.
# :::
#
# ## 1.4 Exploring the contents
#  We have already combine all the data in one dataframe called `Time_series_DATA.txt`.
#
# >Explain that as a engineer/geoscientist we have to take decisions regarding model complexity data sources, etc.
#
# To facilitate this, the following interactive map show the geographical location where the data was collected respect to out system of interest
#
# ```{warning}
# I haven't figured out how to properly load the plot. The plot was created using plotly, but when building the books is does not render correctly, similarly  embedding the HTML of the plot in a md cell does not work either, the file is called 'Geo_tag_stations.html` the code use to create the plot is `Model.ipynb`. see more in the issue in [github](https://github.com/iceclassic/mude/issues/9) . The following is a very crude embedding of the interactive plot.
# ```

# %% [markdown]
# <iframe src="Geo_tag_stations.html" width="100%" height="600"></iframe>

# %% [markdown]
# :::{card} Ex 3
# We have created a simple function called `explore_data.py`. Read the documentation. Then load the dataframe with all the data and *apply* the function.
# Considering the output of the function ¿ Which variables/columns are relevant for our model?
# Explain
# :::

# %%
from funciones import*
import pandas as pd
import numpy as np 
from importlib import reload

Data=pd.read_csv("../../Data/Time_series_DATA.txt",skiprows=149,index_col=0)
#Data=pd.read_csv('https://raw.githubusercontent.com/iceclassic/sandbox/main/Data/Time_series_DATA.txt',index_col=0,skiprows=149)
Data.index = Data.index.astype(str).str.split().str[0]
Data.index = pd.to_datetime(Data.index, format="%Y-%m-%d")

Data = Data[(Data.index.year >= 1915) & (Data.index.year < 2024)]
Data=Data.drop(columns=['Days since start of year','Predicted ice thickness [m]','Noisy predicted ice thickness [m]'])

explore_contents(Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 40413 entries, 1915-01-01 to 2023-12-31
# Data columns (total 23 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Regional: Air temperature [C]                      38563 non-null  float64
#  1   Days until break up                                38563 non-null  float64
#  2   Nenana: Rainfall [mm]                              29516 non-null  float64
#  3   Nenana: Snowfall [mm]                              19945 non-null  float64
#  4   Nenana: Snow depth [mm]                            15984 non-null  float64
#  5   Nenana: Mean water temperature [C]                 2418 non-null   float64
#  6   Nenana: Mean Discharge [m3/s]                      22525 non-null  float64
#  7   Nenana: Air temperature [C]                        31146 non-null  float64
# ...

# %% [markdown]
# :::{card} Ex 4
# You may have noticed that we have at least  three different columns with temperature observation. ¿Should we consider all of them ? Use the function `compare_columns` and decide whether you should use all the columns for our model. Justify your decision
# :::

# %%
temperature_columns=['Regional: Air temperature [C]','Nenana: Air temperature [C]','Fairbanks: Air Temperature [C]',' Gulkana Temperature [C]']
compare_columns(Data,temperature_columns,correlation=True)

# %% [markdown]
# ::: {card} Ex 5
# Assume that you decided that the only relevant temperature data is the one on `Regional: Air Temperature [C]`.
# Use pandas method `.drop` to  eliminate the unnecessary columns
# :::

# %%
Data=Data.drop(columns=temperature_columns[1:])

# %% [markdown]
# Lets do the same for the variables -Rainfall and Snowfall-

# %%
rain_columns=['Nenana: Rainfall [mm]' ,'Fairbanks: Rainfall [mm]','Gulkana Precipitation [mm]']
compare_columns(Data,rain_columns,correlation=True)

# %% [markdown]
# >Perfect, the columns do not to reflect the same phenomena, firstly,  consider the difference between precipitation and rainfall is it the same? >Secondly, the rainfall in Nenana and Fairbanks seem to be uncorrelated, should we drop the column related to Fairbanks and Gulkana glacier then, >as we care about Nenana and from the map, Gulkana is very far away? Maybe, both location are up-river from Nenana and rainfall might have and >effect on the melting of the ice downstream. For the moment, we will drop this column but we will re-examine this decision later on

# %%
Data=Data.drop(columns=rain_columns[1:])

# %% [markdown]
# :::{card} Ex6
# Lets re-examine the sparsity plot obtained form the function`explore_content`.
# Some columns have a very different *sampling frequency* and number of observation than others. Use the `drop` method to eliminate variables that have very dissimilar characteristics
# :::

# %%
sparse_columns=['Regional: Solar Surface Irradiance [W/m2]','Regional: Cloud coverage [%]','Global: ENSO-Southern oscillation index','Gulkana: Glacier-wide winter mass balance [m.w.e]','Gulkana: Glacier-wide summer mass balance [m.w.e]','Global: Pacific decadal oscillation index','Global: Artic oscillation index']
Data=Data.drop(columns=sparse_columns)

# %% [markdown]
# :::{card} Ex7
# We have over 100 years of data in the dataframe. Let's start by only the data staring from 1950. Use [indexing](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html) to select this data from the dataframe  ( here put example as the doc is very extensive. Remember that the date of the observation is in the index.)
#
#
# Use `explore_contents` and compare the output to the first time we used this function
# :::

# %%
Data = Data[(Data.index.year >= 1950)]
explore_contents(Data,opt={'Info':True,'Time History':False,"Sparsity":True})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27916 entries, 1950-01-01 to 2023-12-31
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Regional: Air temperature [C]        26510 non-null  float64
#  1   Days until break up                  26510 non-null  float64
#  2   Nenana: Rainfall [mm]                22235 non-null  float64
#  3   Nenana: Snowfall [mm]                13322 non-null  float64
#  4   Nenana: Snow depth [mm]              12965 non-null  float64
#  5   Nenana: Mean water temperature [C]   2418 non-null   float64
#  6   Nenana: Mean Discharge [m3/s]        22525 non-null  float64
#  7   Fairbanks: Average wind speed [m/s]  9797 non-null   float64
#  8   Fairbanks: Snowfall [mm]             22250 non-null  float64
#  9   Fairbanks: Snow depth [mm]           22250 non-null  float64
# ...

# %% [markdown]
# ## 1.3 Filtering and Accessing Specific Data.
# You may have noticed that the `.drop` method, and the way we limited the range of the data caused permanent changes to the dataframe, which might no be ideal in most cases, that is why we usually create a copy using the method `Copy=Dataframe.copy()`
#
# :::{card} Ex 8
# Create a copy of the dataframe with all the column corresponding to *Nenana*, and another with the column corresponding to *Fairbanks*.
#
# :::

# %%
nenana_cols=['Nenana: Rainfall [mm]','Nenana: Snowfall [mm]','Nenana: Snow depth [mm]','Nenana: Mean water temperature [C]','Nenana: Mean Discharge [m3/s]']
Nenana_Copy=Data[nenana_cols].copy() 
fairbanks_col=['Fairbanks: Average wind speed [m/s]','Fairbanks: Snowfall [mm]','Fairbanks: Snow depth [mm]']
Fairbanks_Copy=Data[fairbanks_col].copy()

# %% [markdown]
# :::{card} Ex 9
# Let's say now, that we want to select the data for `Regional: Air temperature [C]`,`Nenana: Rainfall [mm]`and `IceThickness [cm]`, for the years between 2008-2010 and 2015, 2018. What if now we cant the same but only for winter observations? It is still possible using the method described above but it gets a little bit more complicated. Instead, use the function `filter_df` and  plot only the time-series using `explore_contents` to make sure the filtered df is waht we want.
# :::

# %%
filter_df_2=filter_df(Data,cols=['Regional: Air temperature [C]','Nenana: Rainfall [mm]','IceThickness [cm]'],start_date='01/01',end_date='03/21',multiyear=[2008,20109,2010,2015,2018])
filter_df_2.head()

explore_contents(filter_df_2,opt={'Info':False,'Time History':True,"Sparsity":False})

# %% [markdown]
# ```{warning}
# Once the issues with the interactive plot are fully figured out, put here the time-seres plot wiht the sliders and zoom, button to hide traces,etc
# ```

# %%
# %matplotlib widget

# Assuming Data is your DataFrame and it has the necessary columns
column_groups = {
    'Group 1': ['Regional: Air temperature [C]', 'Nenana: Rainfall [mm]'],
    'Group 2': ['IceThickness [cm]'],
}

# Plot the specified columns with default y_domains and focus on a specific date
plot_columns_interactive(Data, column_groups, title="Break up times & Global Variables at Tenana River-Nenana, AK", xlabel="Date")
