# %% [markdown]
# # Getting the Data

# %%
import pandas as pd

# %%
print("Printing collected metadata ") # maybe add here the license as well
with open('../../data/Time_series_DATA.txt', 'r', encoding='utf-8') as file:
    metadata = [next(file) for _ in range(149)]

for line in metadata:
    print(line.strip())  #

# getting the data
# Out:
# Printing collected metadata
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Description and source of Data
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Data.index
# - Date of event in format (YYYY-MM-DD)
# - Some measurements have different frequencies, therefore we decided to
# - Removed timestamps of events ( only dates)
# - For monthly data, we assume the measurement occurred on the first of that month
# - For yearly data, we assume the measurement occurred on the first day of the first month of that year
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Data['Regional: Air temperature [C]']
# - [Berkeley Earth Global Temperature](https://berkeleyearth.org/)
# - Daily observations
# - Resolution 1° x  1°
# - We consider the average of data in nearest quadrants to Nenana
# ...
